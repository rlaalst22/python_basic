# %% [markdown]
# # POS Tagging : 토큰에 품사를 부착

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

simpleSentence = 'Seoul is te capital of Korea.'
wordsinSentence = nltk.word_tokenize(simpleSentence)
print(wordsinSentence)
partsOfSpeechTags = nltk.pos_tag(wordsinSentence)
print(partsOfSpeechTags)
# Out:
# ['Seoul', 'is', 'te', 'capital', 'of', 'Korea', '.']
# [('Seoul', 'NNP'), ('is', 'VBZ'), ('te', 'JJ'), ('capital', 'NN'), ('of', 'IN'), ('Korea', 'NNP'), ('.', '.')]
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # Own Tagger

# %%
import nltk
def learnDefaultTagger(simpleSentence):
    wordsInSentence = nltk.word_tokenize(simpleSentence)
    tagger = nltk.DefaultTagger('NN')
    posEnabledTags = tagger.tag(wordsInSentence)
    print(posEnabledTags)
def learnRETagger(simpleSentence):
    customPatterns = [
    (r'.*ing$', 'ADJECTIVE'), # running
    (r'.*ly$', 'ADVERB'), # willingly
    (r'.*ion$', 'NOUN'), # intimation
    (r'(.*ate|.*en|is)$', 'VERB'), # terminate, darken, lighten
    (r'^an$', 'INDEFINITE-ARTICLE'), # terminate
    (r'^(with|on|at)$', 'PREPOSITION'), # on
    (r'^\-?[0-9]+(\.[0-9]+)$', 'NUMBER'), # -1.0, 12345.123
    (r'.*$', None),
    ]
    tagger = nltk.RegexpTagger(customPatterns)
    wordsInSentence = nltk.word_tokenize(simpleSentence)
    posEnabledTags = tagger.tag(wordsInSentence)
    print(posEnabledTags)
def learnLookupTagger(simpleSentence):
    mapping = {
    '.': '.', 'place': 'NN', 'on': 'IN',
    'earth': 'NN', 'Reykjavik' : 'NNP', 'is': 'VBZ',
    'an': 'DT', 'amazing': 'JJ'
    }
    tagger = nltk.UnigramTagger(model=mapping)
    wordsInSentence = nltk.word_tokenize(simpleSentence)
    posEnabledTags = tagger.tag(wordsInSentence)
    print(posEnabledTags)
if __name__ == '__main__':
    testSentence = "Reykjavik is an amazing place on earth. I have visited Reykjavik"
    learnDefaultTagger(testSentence)
    print()
    learnRETagger(testSentence)
    print()
    learnLookupTagger(testSentence)
# Out:
# [('Reykjavik', 'NN'), ('is', 'NN'), ('an', 'NN'), ('amazing', 'NN'), ('place', 'NN'), ('on', 'NN'), ('earth', 'NN'), ('.', 'NN'), ('I', 'NN'), ('have', 'NN'), ('visited', 'NN'), ('Reykjavik', 'NN')]
#
# [('Reykjavik', None), ('is', 'VERB'), ('an', 'INDEFINITE-ARTICLE'), ('amazing', 'ADJECTIVE'), ('place', None), ('on', 'PREPOSITION'), ('earth', None), ('.', None), ('I', None), ('have', None), ('visited', None), ('Reykjavik', None)]
#
# [('Reykjavik', 'NNP'), ('is', 'VBZ'), ('an', 'DT'), ('amazing', 'JJ'), ('place', 'NN'), ('on', 'IN'), ('earth', 'NN'), ('.', '.'), ('I', None), ('have', None), ('visited', None), ('Reykjavik', 'NNP')]

# %% [markdown]
# # Train3

# %%
import nltk
import pickle

def sampleData():
    return [
        'Bangalore is the capital of Karnataka.',
        'Steve Jobs was the CEO of Apple.',
        'iPhone was Invented by Apple.',
        'Bookds can be purchased in Market.'
    ]
def buildDictionary():
    dictionary = {}
    for sent in sampleData():
        partsOfSpeechTags = nltk.pos_tag(nltk.word_tokenize(sent))
        for tag in partsOfSpeechTags:
            value = tag[0]
            pos = tag[1]
            dictionary[value] = pos
    return dictionary

def saveMyTagger(tagger, fileName):
    fileHandle = open(fileName,'wb')
    pickle.dump(tagger,fileHandle)
    fileHandle.close()
def saveMyTraining(fileName):
    tagger = nltk.UnigramTagger(model = buildDictionary())
    saveMyTagger(tagger,fileName)
    
def loadMyTagger(fileName):
    return pickle.load(open(fileName,'rb'))
sentence = 'Iphone is purchased by Steve Jobs in Bangalore Market'
fileName = "myTagger.pickle"

saveMyTraining(fileName)
myTagger = loadMyTagger(fileName)
print(myTagger.tag(nltk.word_tokenize(sentence)))
# Out:
# [('Iphone', None), ('is', 'VBZ'), ('purchased', 'VBN'), ('by', 'IN'), ('Steve', 'NNP'), ('Jobs', 'NNP'), ('in', 'IN'), ('Bangalore', 'NNP'), ('Market', 'NNP')]

# %% [markdown]
# # Pickle 예제

# %%
import pickle
ls = ['a','b','c']
with open('list.txt','wb') as f:
    pickle.dump(ls,f)

# %%
with open('list.txt','rb') as f:
    data = pickle.load(f)
    print(data)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# # Grammar

# %%
import nltk
import string
from nltk.parse.generate import generate

productions = [
    'ROOT -> WORD',
    'WORD -> ' '',
    'WORD -> NUMBER LETTER',
    'WORD -> LETTER NUMBER'
]
digits = list(string.digits)
for digit in digits[:4]:
    productions.append("NUMBER -> '{w}'".format(w=digit))

letters = "' | '".join(list(string.ascii_lowercase)[:4])
productions.append("LETTER -> '{w}'".format(w=letters))

grammarString = '\n'.join(productions)

grammar = nltk.CFG.fromstring(grammarString)

print(grammar)

for sentence in generate(grammar,n=100,depth=5):
    palindrome = ''.join(sentence).replace(' ', '')
    print('생성된 단어: {},크기:{}'.format(palindrome,len(palindrome)))
# Out:
# Grammar with 12 productions (start state = ROOT)
#     ROOT -> WORD
#     WORD ->
#     WORD -> NUMBER LETTER
#     WORD -> LETTER NUMBER
#     NUMBER -> '0'
#     NUMBER -> '1'
#     NUMBER -> '2'
#     NUMBER -> '3'
#     LETTER -> 'a'
#     LETTER -> 'b'
#     LETTER -> 'c'
#     LETTER -> 'd'
# 생성된 단어: ,크기:0
# 생성된 단어: 0a,크기:2
# 생성된 단어: 0b,크기:2
# 생성된 단어: 0c,크기:2
# 생성된 단어: 0d,크기:2
# 생성된 단어: 1a,크기:2
# 생성된 단어: 1b,크기:2
# 생성된 단어: 1c,크기:2
# 생성된 단어: 1d,크기:2
# 생성된 단어: 2a,크기:2
# 생성된 단어: 2b,크기:2
# 생성된 단어: 2c,크기:2
# 생성된 단어: 2d,크기:2
# 생성된 단어: 3a,크기:2
# 생성된 단어: 3b,크기:2
# 생성된 단어: 3c,크기:2
# 생성된 단어: 3d,크기:2
# 생성된 단어: a0,크기:2
# 생성된 단어: a1,크기:2
# 생성된 단어: a2,크기:2
# 생성된 단어: a3,크기:2
# 생성된 단어: b0,크기:2
# 생성된 단어: b1,크기:2
# 생성된 단어: b2,크기:2
# 생성된 단어: b3,크기:2
# 생성된 단어: c0,크기:2
# 생성된 단어: c1,크기:2
# 생성된 단어: c2,크기:2
# 생성된 단어: c3,크기:2
# 생성된 단어: d0,크기:2
# 생성된 단어: d1,크기:2
# 생성된 단어: d2,크기:2
# 생성된 단어: d3,크기:2

# %% [markdown]
# # PCFG

# %%
import nltk
from nltk.parse.generate import generate

productions = [
    "ROOT -> WORD [1.0]",
    "WORD -> P1 [0.25]",
    "WORD -> P1 P2 [0.25]",
    "WORD -> P1 P2 P3 [0.25]",
    "WORD -> P1 P2 P3 P4 [0.25]",
    "P1 -> 'A' [1.0]",
    "P2 -> 'B' [0.5]",
    "P2 -> 'C' [0.5]",
    "P3 -> 'D' [0.3]",
    "P3 -> 'E' [0.3]",
    "P3 -> 'F' [0.4]",
    "P4 -> 'G' [0.9]",
    "P4 -> 'H' [0.1]",
]
grammarString = '\n'.join(productions)
grammar = nltk.PCFG.fromstring(grammarString)
print(grammar)

for sentence in generate(grammar,n=10,depth=5):
    palindrome = ''.join(sentence).replace(' ','')
    print('문자열:{},크기:{}'.format(palindrome,len(palindrome)))
# Out:
# Grammar with 13 productions (start state = ROOT)
#     ROOT -> WORD [1.0]
#     WORD -> P1 [0.25]
#     WORD -> P1 P2 [0.25]
#     WORD -> P1 P2 P3 [0.25]
#     WORD -> P1 P2 P3 P4 [0.25]
#     P1 -> 'A' [1.0]
#     P2 -> 'B' [0.5]
#     P2 -> 'C' [0.5]
#     P3 -> 'D' [0.3]
#     P3 -> 'E' [0.3]
#     P3 -> 'F' [0.4]
#     P4 -> 'G' [0.9]
#     P4 -> 'H' [0.1]
# 문자열:A,크기:1
# 문자열:AB,크기:2
# 문자열:AC,크기:2
# 문자열:ABD,크기:3
# 문자열:ABE,크기:3
# 문자열:ABF,크기:3
# 문자열:ACD,크기:3
# 문자열:ACE,크기:3
# 문자열:ACF,크기:3
# 문자열:ABDG,크기:4

# %%
import nltk
import string
from nltk.parse.generate import generate

productions = [
    'ROOT -> WORD',
    'WORD -> ' ''
]
alphabets = list(string.digits)
for alphabet in alphabets:
    productions.append("WORD -> '{w}' WORD '{w}'".format(w=alphabet))

grammarString = '\n'.join(productions)

grammar = nltk.CFG.fromstring(grammarString)

print(grammar)

for sentence in generate(grammar,depth =5):
    palindrome = ''.join(sentence).replace(' ','')
    print('Palindrome : {},size :{}'.format(palindrome,len(palindrome)))
# Out:
# Grammar with 12 productions (start state = ROOT)
#     ROOT -> WORD
#     WORD ->
#     WORD -> '0' WORD '0'
#     WORD -> '1' WORD '1'
#     WORD -> '2' WORD '2'
#     WORD -> '3' WORD '3'
#     WORD -> '4' WORD '4'
#     WORD -> '5' WORD '5'
#     WORD -> '6' WORD '6'
#     WORD -> '7' WORD '7'
#     WORD -> '8' WORD '8'
#     WORD -> '9' WORD '9'
# Palindrome : ,size :0
# Palindrome : 00,size :2
# Palindrome : 0000,size :4
# Palindrome : 000000,size :6
# Palindrome : 001100,size :6
# Palindrome : 002200,size :6
# Palindrome : 003300,size :6
# Palindrome : 004400,size :6
# Palindrome : 005500,size :6
# Palindrome : 006600,size :6
# Palindrome : 007700,size :6
# Palindrome : 008800,size :6
# Palindrome : 009900,size :6
# Palindrome : 0110,size :4
# Palindrome : 010010,size :6
# Palindrome : 011110,size :6
# Palindrome : 012210,size :6
# Palindrome : 013310,size :6
# Palindrome : 014410,size :6
# Palindrome : 015510,size :6
# Palindrome : 016610,size :6
# Palindrome : 017710,size :6
# Palindrome : 018810,size :6
# Palindrome : 019910,size :6
# Palindrome : 0220,size :4
# Palindrome : 020020,size :6
# Palindrome : 021120,size :6
# Palindrome : 022220,size :6
# Palindrome : 023320,size :6
# Palindrome : 024420,size :6
# Palindrome : 025520,size :6
# Palindrome : 026620,size :6
# Palindrome : 027720,size :6
# Palindrome : 028820,size :6
# Palindrome : 029920,size :6
# Palindrome : 0330,size :4
# Palindrome : 030030,size :6
# Palindrome : 031130,size :6
# Palindrome : 032230,size :6
# Palindrome : 033330,size :6
# Palindrome : 034430,size :6
# Palindrome : 035530,size :6
# Palindrome : 036630,size :6
# Palindrome : 037730,size :6
# Palindrome : 038830,size :6
# Palindrome : 039930,size :6
# Palindrome : 0440,size :4
# Palindrome : 040040,size :6
# Palindrome : 041140,size :6
# Palindrome : 042240,size :6
# Palindrome : 043340,size :6
# Palindrome : 044440,size :6
# Palindrome : 045540,size :6
# Palindrome : 046640,size :6
# Palindrome : 047740,size :6
# Palindrome : 048840,size :6
# Palindrome : 049940,size :6
# Palindrome : 0550,size :4
# Palindrome : 050050,size :6
# Palindrome : 051150,size :6
# Palindrome : 052250,size :6
# Palindrome : 053350,size :6
# Palindrome : 054450,size :6
# Palindrome : 055550,size :6
# Palindrome : 056650,size :6
# Palindrome : 057750,size :6
# Palindrome : 058850,size :6
# Palindrome : 059950,size :6
# Palindrome : 0660,size :4
# Palindrome : 060060,size :6
# Palindrome : 061160,size :6
# Palindrome : 062260,size :6
# Palindrome : 063360,size :6
# Palindrome : 064460,size :6
# Palindrome : 065560,size :6
# Palindrome : 066660,size :6
# Palindrome : 067760,size :6
# Palindrome : 068860,size :6
# Palindrome : 069960,size :6
# Palindrome : 0770,size :4
# Palindrome : 070070,size :6
# Palindrome : 071170,size :6
# Palindrome : 072270,size :6
# Palindrome : 073370,size :6
# Palindrome : 074470,size :6
# Palindrome : 075570,size :6
# Palindrome : 076670,size :6
# Palindrome : 077770,size :6
# Palindrome : 078870,size :6
# Palindrome : 079970,size :6
# Palindrome : 0880,size :4
# Palindrome : 080080,size :6
# Palindrome : 081180,size :6
# Palindrome : 082280,size :6
# Palindrome : 083380,size :6
# Palindrome : 084480,size :6
# Palindrome : 085580,size :6
# Palindrome : 086680,size :6
# Palindrome : 087780,size :6
# Palindrome : 088880,size :6
# Palindrome : 089980,size :6
# Palindrome : 0990,size :4
# Palindrome : 090090,size :6
# Palindrome : 091190,size :6
# Palindrome : 092290,size :6
# Palindrome : 093390,size :6
# Palindrome : 094490,size :6
# Palindrome : 095590,size :6
# Palindrome : 096690,size :6
# Palindrome : 097790,size :6
# Palindrome : 098890,size :6
# Palindrome : 099990,size :6
# Palindrome : 11,size :2
# Palindrome : 1001,size :4
# Palindrome : 100001,size :6
# Palindrome : 101101,size :6
# Palindrome : 102201,size :6
# Palindrome : 103301,size :6
# Palindrome : 104401,size :6
# Palindrome : 105501,size :6
# Palindrome : 106601,size :6
# Palindrome : 107701,size :6
# Palindrome : 108801,size :6
# Palindrome : 109901,size :6
# Palindrome : 1111,size :4
# Palindrome : 110011,size :6
# Palindrome : 111111,size :6
# Palindrome : 112211,size :6
# Palindrome : 113311,size :6
# Palindrome : 114411,size :6
# Palindrome : 115511,size :6
# Palindrome : 116611,size :6
# Palindrome : 117711,size :6
# Palindrome : 118811,size :6
# Palindrome : 119911,size :6
# Palindrome : 1221,size :4
# Palindrome : 120021,size :6
# Palindrome : 121121,size :6
# Palindrome : 122221,size :6
# Palindrome : 123321,size :6
# Palindrome : 124421,size :6
# Palindrome : 125521,size :6
# Palindrome : 126621,size :6
# Palindrome : 127721,size :6
# Palindrome : 128821,size :6
# Palindrome : 129921,size :6
# Palindrome : 1331,size :4
# Palindrome : 130031,size :6
# Palindrome : 131131,size :6
# Palindrome : 132231,size :6
# Palindrome : 133331,size :6
# Palindrome : 134431,size :6
# Palindrome : 135531,size :6
# Palindrome : 136631,size :6
# Palindrome : 137731,size :6
# Palindrome : 138831,size :6
# Palindrome : 139931,size :6
# Palindrome : 1441,size :4
# Palindrome : 140041,size :6
# Palindrome : 141141,size :6
# Palindrome : 142241,size :6
# Palindrome : 143341,size :6
# Palindrome : 144441,size :6
# Palindrome : 145541,size :6
# Palindrome : 146641,size :6
# Palindrome : 147741,size :6
# Palindrome : 148841,size :6
# Palindrome : 149941,size :6
# Palindrome : 1551,size :4
# Palindrome : 150051,size :6
# Palindrome : 151151,size :6
# Palindrome : 152251,size :6
# Palindrome : 153351,size :6
# Palindrome : 154451,size :6
# Palindrome : 155551,size :6
# Palindrome : 156651,size :6
# Palindrome : 157751,size :6
# Palindrome : 158851,size :6
# Palindrome : 159951,size :6
# Palindrome : 1661,size :4
# Palindrome : 160061,size :6
# Palindrome : 161161,size :6
# Palindrome : 162261,size :6
# Palindrome : 163361,size :6
# Palindrome : 164461,size :6
# Palindrome : 165561,size :6
# Palindrome : 166661,size :6
# Palindrome : 167761,size :6
# Palindrome : 168861,size :6
# Palindrome : 169961,size :6
# Palindrome : 1771,size :4
# Palindrome : 170071,size :6
# Palindrome : 171171,size :6
# Palindrome : 172271,size :6
# Palindrome : 173371,size :6
# Palindrome : 174471,size :6
# Palindrome : 175571,size :6
# Palindrome : 176671,size :6
# Palindrome : 177771,size :6
# Palindrome : 178871,size :6
# Palindrome : 179971,size :6
# Palindrome : 1881,size :4
# Palindrome : 180081,size :6
# Palindrome : 181181,size :6
# Palindrome : 182281,size :6
# Palindrome : 183381,size :6
# Palindrome : 184481,size :6
# Palindrome : 185581,size :6
# Palindrome : 186681,size :6
# Palindrome : 187781,size :6
# Palindrome : 188881,size :6
# Palindrome : 189981,size :6
# Palindrome : 1991,size :4
# Palindrome : 190091,size :6
# Palindrome : 191191,size :6
# Palindrome : 192291,size :6
# Palindrome : 193391,size :6
# Palindrome : 194491,size :6
# Palindrome : 195591,size :6
# Palindrome : 196691,size :6
# Palindrome : 197791,size :6
# Palindrome : 198891,size :6
# Palindrome : 199991,size :6
# Palindrome : 22,size :2
# Palindrome : 2002,size :4
# Palindrome : 200002,size :6
# Palindrome : 201102,size :6
# Palindrome : 202202,size :6
# Palindrome : 203302,size :6
# Palindrome : 204402,size :6
# Palindrome : 205502,size :6
# Palindrome : 206602,size :6
# Palindrome : 207702,size :6
# Palindrome : 208802,size :6
# Palindrome : 209902,size :6
# Palindrome : 2112,size :4
# Palindrome : 210012,size :6
# Palindrome : 211112,size :6
# Palindrome : 212212,size :6
# Palindrome : 213312,size :6
# Palindrome : 214412,size :6
# Palindrome : 215512,size :6
# Palindrome : 216612,size :6
# Palindrome : 217712,size :6
# Palindrome : 218812,size :6
# Palindrome : 219912,size :6
# Palindrome : 2222,size :4
# Palindrome : 220022,size :6
# Palindrome : 221122,size :6
# Palindrome : 222222,size :6
# Palindrome : 223322,size :6
# Palindrome : 224422,size :6
# Palindrome : 225522,size :6
# Palindrome : 226622,size :6
# Palindrome : 227722,size :6
# Palindrome : 228822,size :6
# Palindrome : 229922,size :6
# Palindrome : 2332,size :4
# Palindrome : 230032,size :6
# Palindrome : 231132,size :6
# Palindrome : 232232,size :6
# Palindrome : 233332,size :6
# Palindrome : 234432,size :6
# Palindrome : 235532,size :6
# Palindrome : 236632,size :6
# Palindrome : 237732,size :6
# Palindrome : 238832,size :6
# Palindrome : 239932,size :6
# Palindrome : 2442,size :4
# Palindrome : 240042,size :6
# Palindrome : 241142,size :6
# Palindrome : 242242,size :6
# Palindrome : 243342,size :6
# Palindrome : 244442,size :6
# Palindrome : 245542,size :6
# Palindrome : 246642,size :6
# Palindrome : 247742,size :6
# Palindrome : 248842,size :6
# Palindrome : 249942,size :6
# Palindrome : 2552,size :4
# Palindrome : 250052,size :6
# Palindrome : 251152,size :6
# Palindrome : 252252,size :6
# Palindrome : 253352,size :6
# Palindrome : 254452,size :6
# Palindrome : 255552,size :6
# Palindrome : 256652,size :6
# Palindrome : 257752,size :6
# Palindrome : 258852,size :6
# Palindrome : 259952,size :6
# Palindrome : 2662,size :4
# Palindrome : 260062,size :6
# Palindrome : 261162,size :6
# Palindrome : 262262,size :6
# Palindrome : 263362,size :6
# Palindrome : 264462,size :6
# Palindrome : 265562,size :6
# Palindrome : 266662,size :6
# Palindrome : 267762,size :6
# Palindrome : 268862,size :6
# Palindrome : 269962,size :6
# Palindrome : 2772,size :4
# Palindrome : 270072,size :6
# Palindrome : 271172,size :6
# Palindrome : 272272,size :6
# Palindrome : 273372,size :6
# Palindrome : 274472,size :6
# Palindrome : 275572,size :6
# Palindrome : 276672,size :6
# Palindrome : 277772,size :6
# Palindrome : 278872,size :6
# Palindrome : 279972,size :6
# Palindrome : 2882,size :4
# Palindrome : 280082,size :6
# Palindrome : 281182,size :6
# Palindrome : 282282,size :6
# Palindrome : 283382,size :6
# Palindrome : 284482,size :6
# Palindrome : 285582,size :6
# Palindrome : 286682,size :6
# Palindrome : 287782,size :6
# Palindrome : 288882,size :6
# Palindrome : 289982,size :6
# Palindrome : 2992,size :4
# Palindrome : 290092,size :6
# Palindrome : 291192,size :6
# Palindrome : 292292,size :6
# Palindrome : 293392,size :6
# Palindrome : 294492,size :6
# Palindrome : 295592,size :6
# Palindrome : 296692,size :6
# Palindrome : 297792,size :6
# Palindrome : 298892,size :6
# Palindrome : 299992,size :6
# Palindrome : 33,size :2
# Palindrome : 3003,size :4
# Palindrome : 300003,size :6
# Palindrome : 301103,size :6
# Palindrome : 302203,size :6
# Palindrome : 303303,size :6
# Palindrome : 304403,size :6
# Palindrome : 305503,size :6
# Palindrome : 306603,size :6
# Palindrome : 307703,size :6
# Palindrome : 308803,size :6
# Palindrome : 309903,size :6
# Palindrome : 3113,size :4
# Palindrome : 310013,size :6
# Palindrome : 311113,size :6
# Palindrome : 312213,size :6
# Palindrome : 313313,size :6
# Palindrome : 314413,size :6
# Palindrome : 315513,size :6
# Palindrome : 316613,size :6
# Palindrome : 317713,size :6
# Palindrome : 318813,size :6
# Palindrome : 319913,size :6
# Palindrome : 3223,size :4
# Palindrome : 320023,size :6
# Palindrome : 321123,size :6
# Palindrome : 322223,size :6
# Palindrome : 323323,size :6
# Palindrome : 324423,size :6
# Palindrome : 325523,size :6
# Palindrome : 326623,size :6
# Palindrome : 327723,size :6
# Palindrome : 328823,size :6
# Palindrome : 329923,size :6
# Palindrome : 3333,size :4
# Palindrome : 330033,size :6
# Palindrome : 331133,size :6
# Palindrome : 332233,size :6
# Palindrome : 333333,size :6
# Palindrome : 334433,size :6
# Palindrome : 335533,size :6
# Palindrome : 336633,size :6
# Palindrome : 337733,size :6
# Palindrome : 338833,size :6
# Palindrome : 339933,size :6
# Palindrome : 3443,size :4
# Palindrome : 340043,size :6
# Palindrome : 341143,size :6
# Palindrome : 342243,size :6
# Palindrome : 343343,size :6
# Palindrome : 344443,size :6
# Palindrome : 345543,size :6
# Palindrome : 346643,size :6
# Palindrome : 347743,size :6
# Palindrome : 348843,size :6
# Palindrome : 349943,size :6
# Palindrome : 3553,size :4
# Palindrome : 350053,size :6
# Palindrome : 351153,size :6
# Palindrome : 352253,size :6
# Palindrome : 353353,size :6
# Palindrome : 354453,size :6
# Palindrome : 355553,size :6
# Palindrome : 356653,size :6
# Palindrome : 357753,size :6
# Palindrome : 358853,size :6
# Palindrome : 359953,size :6
# Palindrome : 3663,size :4
# Palindrome : 360063,size :6
# Palindrome : 361163,size :6
# Palindrome : 362263,size :6
# Palindrome : 363363,size :6
# Palindrome : 364463,size :6
# Palindrome : 365563,size :6
# Palindrome : 366663,size :6
# Palindrome : 367763,size :6
# Palindrome : 368863,size :6
# Palindrome : 369963,size :6
# Palindrome : 3773,size :4
# Palindrome : 370073,size :6
# Palindrome : 371173,size :6
# Palindrome : 372273,size :6
# Palindrome : 373373,size :6
# Palindrome : 374473,size :6
# Palindrome : 375573,size :6
# Palindrome : 376673,size :6
# Palindrome : 377773,size :6
# Palindrome : 378873,size :6
# Palindrome : 379973,size :6
# Palindrome : 3883,size :4
# Palindrome : 380083,size :6
# Palindrome : 381183,size :6
# Palindrome : 382283,size :6
# Palindrome : 383383,size :6
# Palindrome : 384483,size :6
# Palindrome : 385583,size :6
# Palindrome : 386683,size :6
# Palindrome : 387783,size :6
# Palindrome : 388883,size :6
# Palindrome : 389983,size :6
# Palindrome : 3993,size :4
# Palindrome : 390093,size :6
# Palindrome : 391193,size :6
# Palindrome : 392293,size :6
# Palindrome : 393393,size :6
# Palindrome : 394493,size :6
# Palindrome : 395593,size :6
# Palindrome : 396693,size :6
# Palindrome : 397793,size :6
# Palindrome : 398893,size :6
# Palindrome : 399993,size :6
# Palindrome : 44,size :2
# Palindrome : 4004,size :4
# Palindrome : 400004,size :6
# Palindrome : 401104,size :6
# Palindrome : 402204,size :6
# Palindrome : 403304,size :6
# Palindrome : 404404,size :6
# Palindrome : 405504,size :6
# Palindrome : 406604,size :6
# Palindrome : 407704,size :6
# Palindrome : 408804,size :6
# Palindrome : 409904,size :6
# Palindrome : 4114,size :4
# Palindrome : 410014,size :6
# Palindrome : 411114,size :6
# Palindrome : 412214,size :6
# Palindrome : 413314,size :6
# Palindrome : 414414,size :6
# Palindrome : 415514,size :6
# Palindrome : 416614,size :6
# Palindrome : 417714,size :6
# Palindrome : 418814,size :6
# Palindrome : 419914,size :6
# Palindrome : 4224,size :4
# Palindrome : 420024,size :6
# Palindrome : 421124,size :6
# Palindrome : 422224,size :6
# Palindrome : 423324,size :6
# Palindrome : 424424,size :6
# Palindrome : 425524,size :6
# Palindrome : 426624,size :6
# Palindrome : 427724,size :6
# Palindrome : 428824,size :6
# Palindrome : 429924,size :6
# Palindrome : 4334,size :4
# Palindrome : 430034,size :6
# Palindrome : 431134,size :6
# Palindrome : 432234,size :6
# Palindrome : 433334,size :6
# Palindrome : 434434,size :6
# Palindrome : 435534,size :6
# Palindrome : 436634,size :6
# Palindrome : 437734,size :6
# Palindrome : 438834,size :6
# Palindrome : 439934,size :6
# Palindrome : 4444,size :4
# Palindrome : 440044,size :6
# Palindrome : 441144,size :6
# Palindrome : 442244,size :6
# Palindrome : 443344,size :6
# Palindrome : 444444,size :6
# Palindrome : 445544,size :6
# Palindrome : 446644,size :6
# Palindrome : 447744,size :6
# Palindrome : 448844,size :6
# Palindrome : 449944,size :6
# Palindrome : 4554,size :4
# Palindrome : 450054,size :6
# Palindrome : 451154,size :6
# Palindrome : 452254,size :6
# Palindrome : 453354,size :6
# Palindrome : 454454,size :6
# Palindrome : 455554,size :6
# Palindrome : 456654,size :6
# Palindrome : 457754,size :6
# Palindrome : 458854,size :6
# Palindrome : 459954,size :6
# Palindrome : 4664,size :4
# Palindrome : 460064,size :6
# Palindrome : 461164,size :6
# Palindrome : 462264,size :6
# Palindrome : 463364,size :6
# Palindrome : 464464,size :6
# Palindrome : 465564,size :6
# Palindrome : 466664,size :6
# Palindrome : 467764,size :6
# Palindrome : 468864,size :6
# Palindrome : 469964,size :6
# Palindrome : 4774,size :4
# Palindrome : 470074,size :6
# Palindrome : 471174,size :6
# Palindrome : 472274,size :6
# Palindrome : 473374,size :6
# Palindrome : 474474,size :6
# Palindrome : 475574,size :6
# Palindrome : 476674,size :6
# Palindrome : 477774,size :6
# Palindrome : 478874,size :6
# Palindrome : 479974,size :6
# Palindrome : 4884,size :4
# Palindrome : 480084,size :6
# Palindrome : 481184,size :6
# Palindrome : 482284,size :6
# Palindrome : 483384,size :6
# Palindrome : 484484,size :6
# Palindrome : 485584,size :6
# Palindrome : 486684,size :6
# Palindrome : 487784,size :6
# Palindrome : 488884,size :6
# Palindrome : 489984,size :6
# Palindrome : 4994,size :4
# Palindrome : 490094,size :6
# Palindrome : 491194,size :6
# Palindrome : 492294,size :6
# Palindrome : 493394,size :6
# Palindrome : 494494,size :6
# Palindrome : 495594,size :6
# Palindrome : 496694,size :6
# Palindrome : 497794,size :6
# Palindrome : 498894,size :6
# Palindrome : 499994,size :6
# Palindrome : 55,size :2
# Palindrome : 5005,size :4
# Palindrome : 500005,size :6
# Palindrome : 501105,size :6
# Palindrome : 502205,size :6
# Palindrome : 503305,size :6
# Palindrome : 504405,size :6
# Palindrome : 505505,size :6
# Palindrome : 506605,size :6
# Palindrome : 507705,size :6
# Palindrome : 508805,size :6
# Palindrome : 509905,size :6
# Palindrome : 5115,size :4
# Palindrome : 510015,size :6
# Palindrome : 511115,size :6
# Palindrome : 512215,size :6
# Palindrome : 513315,size :6
# Palindrome : 514415,size :6
# Palindrome : 515515,size :6
# Palindrome : 516615,size :6
# Palindrome : 517715,size :6
# Palindrome : 518815,size :6
# Palindrome : 519915,size :6
# Palindrome : 5225,size :4
# Palindrome : 520025,size :6
# Palindrome : 521125,size :6
# Palindrome : 522225,size :6
# Palindrome : 523325,size :6
# Palindrome : 524425,size :6
# Palindrome : 525525,size :6
# Palindrome : 526625,size :6
# Palindrome : 527725,size :6
# Palindrome : 528825,size :6
# Palindrome : 529925,size :6
# Palindrome : 5335,size :4
# Palindrome : 530035,size :6
# Palindrome : 531135,size :6
# Palindrome : 532235,size :6
# Palindrome : 533335,size :6
# Palindrome : 534435,size :6
# Palindrome : 535535,size :6
# Palindrome : 536635,size :6
# Palindrome : 537735,size :6
# Palindrome : 538835,size :6
# Palindrome : 539935,size :6
# Palindrome : 5445,size :4
# Palindrome : 540045,size :6
# Palindrome : 541145,size :6
# Palindrome : 542245,size :6
# Palindrome : 543345,size :6
# Palindrome : 544445,size :6
# Palindrome : 545545,size :6
# Palindrome : 546645,size :6
# Palindrome : 547745,size :6
# Palindrome : 548845,size :6
# Palindrome : 549945,size :6
# Palindrome : 5555,size :4
# Palindrome : 550055,size :6
# Palindrome : 551155,size :6
# Palindrome : 552255,size :6
# Palindrome : 553355,size :6
# Palindrome : 554455,size :6
# Palindrome : 555555,size :6
# Palindrome : 556655,size :6
# Palindrome : 557755,size :6
# Palindrome : 558855,size :6
# Palindrome : 559955,size :6
# Palindrome : 5665,size :4
# Palindrome : 560065,size :6
# Palindrome : 561165,size :6
# Palindrome : 562265,size :6
# Palindrome : 563365,size :6
# Palindrome : 564465,size :6
# Palindrome : 565565,size :6
# Palindrome : 566665,size :6
# Palindrome : 567765,size :6
# Palindrome : 568865,size :6
# Palindrome : 569965,size :6
# Palindrome : 5775,size :4
# Palindrome : 570075,size :6
# Palindrome : 571175,size :6
# Palindrome : 572275,size :6
# Palindrome : 573375,size :6
# Palindrome : 574475,size :6
# Palindrome : 575575,size :6
# Palindrome : 576675,size :6
# Palindrome : 577775,size :6
# Palindrome : 578875,size :6
# Palindrome : 579975,size :6
# Palindrome : 5885,size :4
# Palindrome : 580085,size :6
# Palindrome : 581185,size :6
# Palindrome : 582285,size :6
# Palindrome : 583385,size :6
# Palindrome : 584485,size :6
# Palindrome : 585585,size :6
# Palindrome : 586685,size :6
# Palindrome : 587785,size :6
# Palindrome : 588885,size :6
# Palindrome : 589985,size :6
# Palindrome : 5995,size :4
# Palindrome : 590095,size :6
# Palindrome : 591195,size :6
# Palindrome : 592295,size :6
# Palindrome : 593395,size :6
# Palindrome : 594495,size :6
# Palindrome : 595595,size :6
# Palindrome : 596695,size :6
# Palindrome : 597795,size :6
# Palindrome : 598895,size :6
# Palindrome : 599995,size :6
# Palindrome : 66,size :2
# Palindrome : 6006,size :4
# Palindrome : 600006,size :6
# Palindrome : 601106,size :6
# Palindrome : 602206,size :6
# Palindrome : 603306,size :6
# Palindrome : 604406,size :6
# Palindrome : 605506,size :6
# Palindrome : 606606,size :6
# Palindrome : 607706,size :6
# Palindrome : 608806,size :6
# Palindrome : 609906,size :6
# Palindrome : 6116,size :4
# Palindrome : 610016,size :6
# Palindrome : 611116,size :6
# Palindrome : 612216,size :6
# Palindrome : 613316,size :6
# Palindrome : 614416,size :6
# Palindrome : 615516,size :6
# Palindrome : 616616,size :6
# Palindrome : 617716,size :6
# Palindrome : 618816,size :6
# Palindrome : 619916,size :6
# Palindrome : 6226,size :4
# Palindrome : 620026,size :6
# Palindrome : 621126,size :6
# Palindrome : 622226,size :6
# Palindrome : 623326,size :6
# Palindrome : 624426,size :6
# Palindrome : 625526,size :6
# Palindrome : 626626,size :6
# Palindrome : 627726,size :6
# Palindrome : 628826,size :6
# Palindrome : 629926,size :6
# Palindrome : 6336,size :4
# Palindrome : 630036,size :6
# Palindrome : 631136,size :6
# Palindrome : 632236,size :6
# Palindrome : 633336,size :6
# Palindrome : 634436,size :6
# Palindrome : 635536,size :6
# Palindrome : 636636,size :6
# Palindrome : 637736,size :6
# Palindrome : 638836,size :6
# Palindrome : 639936,size :6
# Palindrome : 6446,size :4
# Palindrome : 640046,size :6
# Palindrome : 641146,size :6
# Palindrome : 642246,size :6
# Palindrome : 643346,size :6
# Palindrome : 644446,size :6
# Palindrome : 645546,size :6
# Palindrome : 646646,size :6
# Palindrome : 647746,size :6
# Palindrome : 648846,size :6
# Palindrome : 649946,size :6
# Palindrome : 6556,size :4
# Palindrome : 650056,size :6
# Palindrome : 651156,size :6
# Palindrome : 652256,size :6
# Palindrome : 653356,size :6
# Palindrome : 654456,size :6
# Palindrome : 655556,size :6
# Palindrome : 656656,size :6
# Palindrome : 657756,size :6
# Palindrome : 658856,size :6
# Palindrome : 659956,size :6
# Palindrome : 6666,size :4
# Palindrome : 660066,size :6
# Palindrome : 661166,size :6
# Palindrome : 662266,size :6
# Palindrome : 663366,size :6
# Palindrome : 664466,size :6
# Palindrome : 665566,size :6
# Palindrome : 666666,size :6
# Palindrome : 667766,size :6
# Palindrome : 668866,size :6
# Palindrome : 669966,size :6
# Palindrome : 6776,size :4
# Palindrome : 670076,size :6
# Palindrome : 671176,size :6
# Palindrome : 672276,size :6
# Palindrome : 673376,size :6
# Palindrome : 674476,size :6
# Palindrome : 675576,size :6
# Palindrome : 676676,size :6
# Palindrome : 677776,size :6
# Palindrome : 678876,size :6
# Palindrome : 679976,size :6
# Palindrome : 6886,size :4
# Palindrome : 680086,size :6
# Palindrome : 681186,size :6
# Palindrome : 682286,size :6
# Palindrome : 683386,size :6
# Palindrome : 684486,size :6
# Palindrome : 685586,size :6
# Palindrome : 686686,size :6
# Palindrome : 687786,size :6
# Palindrome : 688886,size :6
# Palindrome : 689986,size :6
# Palindrome : 6996,size :4
# Palindrome : 690096,size :6
# Palindrome : 691196,size :6
# Palindrome : 692296,size :6
# Palindrome : 693396,size :6
# Palindrome : 694496,size :6
# Palindrome : 695596,size :6
# Palindrome : 696696,size :6
# Palindrome : 697796,size :6
# Palindrome : 698896,size :6
# Palindrome : 699996,size :6
# Palindrome : 77,size :2
# Palindrome : 7007,size :4
# Palindrome : 700007,size :6
# Palindrome : 701107,size :6
# Palindrome : 702207,size :6
# Palindrome : 703307,size :6
# Palindrome : 704407,size :6
# Palindrome : 705507,size :6
# Palindrome : 706607,size :6
# Palindrome : 707707,size :6
# Palindrome : 708807,size :6
# Palindrome : 709907,size :6
# Palindrome : 7117,size :4
# Palindrome : 710017,size :6
# Palindrome : 711117,size :6
# Palindrome : 712217,size :6
# Palindrome : 713317,size :6
# Palindrome : 714417,size :6
# Palindrome : 715517,size :6
# Palindrome : 716617,size :6
# Palindrome : 717717,size :6
# Palindrome : 718817,size :6
# Palindrome : 719917,size :6
# Palindrome : 7227,size :4
# Palindrome : 720027,size :6
# Palindrome : 721127,size :6
# Palindrome : 722227,size :6
# Palindrome : 723327,size :6
# Palindrome : 724427,size :6
# Palindrome : 725527,size :6
# Palindrome : 726627,size :6
# Palindrome : 727727,size :6
# Palindrome : 728827,size :6
# Palindrome : 729927,size :6
# Palindrome : 7337,size :4
# Palindrome : 730037,size :6
# Palindrome : 731137,size :6
# Palindrome : 732237,size :6
# Palindrome : 733337,size :6
# Palindrome : 734437,size :6
# Palindrome : 735537,size :6
# Palindrome : 736637,size :6
# Palindrome : 737737,size :6
# Palindrome : 738837,size :6
# Palindrome : 739937,size :6
# Palindrome : 7447,size :4
# Palindrome : 740047,size :6
# Palindrome : 741147,size :6
# Palindrome : 742247,size :6
# Palindrome : 743347,size :6
# Palindrome : 744447,size :6
# Palindrome : 745547,size :6
# Palindrome : 746647,size :6
# Palindrome : 747747,size :6
# Palindrome : 748847,size :6
# Palindrome : 749947,size :6
# Palindrome : 7557,size :4
# Palindrome : 750057,size :6
# Palindrome : 751157,size :6
# Palindrome : 752257,size :6
# Palindrome : 753357,size :6
# Palindrome : 754457,size :6
# Palindrome : 755557,size :6
# Palindrome : 756657,size :6
# Palindrome : 757757,size :6
# Palindrome : 758857,size :6
# Palindrome : 759957,size :6
# Palindrome : 7667,size :4
# Palindrome : 760067,size :6
# Palindrome : 761167,size :6
# Palindrome : 762267,size :6
# Palindrome : 763367,size :6
# Palindrome : 764467,size :6
# Palindrome : 765567,size :6
# Palindrome : 766667,size :6
# Palindrome : 767767,size :6
# Palindrome : 768867,size :6
# Palindrome : 769967,size :6
# Palindrome : 7777,size :4
# Palindrome : 770077,size :6
# Palindrome : 771177,size :6
# Palindrome : 772277,size :6
# Palindrome : 773377,size :6
# Palindrome : 774477,size :6
# Palindrome : 775577,size :6
# Palindrome : 776677,size :6
# Palindrome : 777777,size :6
# Palindrome : 778877,size :6
# Palindrome : 779977,size :6
# Palindrome : 7887,size :4
# Palindrome : 780087,size :6
# Palindrome : 781187,size :6
# Palindrome : 782287,size :6
# Palindrome : 783387,size :6
# Palindrome : 784487,size :6
# Palindrome : 785587,size :6
# Palindrome : 786687,size :6
# Palindrome : 787787,size :6
# Palindrome : 788887,size :6
# Palindrome : 789987,size :6
# Palindrome : 7997,size :4
# Palindrome : 790097,size :6
# Palindrome : 791197,size :6
# Palindrome : 792297,size :6
# Palindrome : 793397,size :6
# Palindrome : 794497,size :6
# Palindrome : 795597,size :6
# Palindrome : 796697,size :6
# Palindrome : 797797,size :6
# Palindrome : 798897,size :6
# Palindrome : 799997,size :6
# Palindrome : 88,size :2
# Palindrome : 8008,size :4
# Palindrome : 800008,size :6
# Palindrome : 801108,size :6
# Palindrome : 802208,size :6
# Palindrome : 803308,size :6
# Palindrome : 804408,size :6
# Palindrome : 805508,size :6
# Palindrome : 806608,size :6
# Palindrome : 807708,size :6
# Palindrome : 808808,size :6
# Palindrome : 809908,size :6
# Palindrome : 8118,size :4
# Palindrome : 810018,size :6
# Palindrome : 811118,size :6
# Palindrome : 812218,size :6
# Palindrome : 813318,size :6
# Palindrome : 814418,size :6
# Palindrome : 815518,size :6
# Palindrome : 816618,size :6
# Palindrome : 817718,size :6
# Palindrome : 818818,size :6
# Palindrome : 819918,size :6
# Palindrome : 8228,size :4
# Palindrome : 820028,size :6
# Palindrome : 821128,size :6
# Palindrome : 822228,size :6
# Palindrome : 823328,size :6
# Palindrome : 824428,size :6
# Palindrome : 825528,size :6
# Palindrome : 826628,size :6
# Palindrome : 827728,size :6
# Palindrome : 828828,size :6
# Palindrome : 829928,size :6
# Palindrome : 8338,size :4
# Palindrome : 830038,size :6
# Palindrome : 831138,size :6
# Palindrome : 832238,size :6
# Palindrome : 833338,size :6
# Palindrome : 834438,size :6
# Palindrome : 835538,size :6
# Palindrome : 836638,size :6
# Palindrome : 837738,size :6
# Palindrome : 838838,size :6
# Palindrome : 839938,size :6
# Palindrome : 8448,size :4
# Palindrome : 840048,size :6
# Palindrome : 841148,size :6
# Palindrome : 842248,size :6
# Palindrome : 843348,size :6
# Palindrome : 844448,size :6
# Palindrome : 845548,size :6
# Palindrome : 846648,size :6
# Palindrome : 847748,size :6
# Palindrome : 848848,size :6
# Palindrome : 849948,size :6
# Palindrome : 8558,size :4
# Palindrome : 850058,size :6
# Palindrome : 851158,size :6
# Palindrome : 852258,size :6
# Palindrome : 853358,size :6
# Palindrome : 854458,size :6
# Palindrome : 855558,size :6
# Palindrome : 856658,size :6
# Palindrome : 857758,size :6
# Palindrome : 858858,size :6
# Palindrome : 859958,size :6
# Palindrome : 8668,size :4
# Palindrome : 860068,size :6
# Palindrome : 861168,size :6
# Palindrome : 862268,size :6
# Palindrome : 863368,size :6
# Palindrome : 864468,size :6
# Palindrome : 865568,size :6
# Palindrome : 866668,size :6
# Palindrome : 867768,size :6
# Palindrome : 868868,size :6
# Palindrome : 869968,size :6
# Palindrome : 8778,size :4
# Palindrome : 870078,size :6
# Palindrome : 871178,size :6
# Palindrome : 872278,size :6
# Palindrome : 873378,size :6
# Palindrome : 874478,size :6
# Palindrome : 875578,size :6
# Palindrome : 876678,size :6
# Palindrome : 877778,size :6
# Palindrome : 878878,size :6
# Palindrome : 879978,size :6
# Palindrome : 8888,size :4
# Palindrome : 880088,size :6
# Palindrome : 881188,size :6
# Palindrome : 882288,size :6
# Palindrome : 883388,size :6
# Palindrome : 884488,size :6
# Palindrome : 885588,size :6
# Palindrome : 886688,size :6
# Palindrome : 887788,size :6
# Palindrome : 888888,size :6
# Palindrome : 889988,size :6
# Palindrome : 8998,size :4
# Palindrome : 890098,size :6
# Palindrome : 891198,size :6
# Palindrome : 892298,size :6
# Palindrome : 893398,size :6
# Palindrome : 894498,size :6
# Palindrome : 895598,size :6
# Palindrome : 896698,size :6
# Palindrome : 897798,size :6
# Palindrome : 898898,size :6
# Palindrome : 899998,size :6
# Palindrome : 99,size :2
# Palindrome : 9009,size :4
# Palindrome : 900009,size :6
# Palindrome : 901109,size :6
# Palindrome : 902209,size :6
# Palindrome : 903309,size :6
# Palindrome : 904409,size :6
# Palindrome : 905509,size :6
# Palindrome : 906609,size :6
# Palindrome : 907709,size :6
# Palindrome : 908809,size :6
# Palindrome : 909909,size :6
# Palindrome : 9119,size :4
# Palindrome : 910019,size :6
# Palindrome : 911119,size :6
# Palindrome : 912219,size :6
# Palindrome : 913319,size :6
# Palindrome : 914419,size :6
# Palindrome : 915519,size :6
# Palindrome : 916619,size :6
# Palindrome : 917719,size :6
# Palindrome : 918819,size :6
# Palindrome : 919919,size :6
# Palindrome : 9229,size :4
# Palindrome : 920029,size :6
# Palindrome : 921129,size :6
# Palindrome : 922229,size :6
# Palindrome : 923329,size :6
# Palindrome : 924429,size :6
# Palindrome : 925529,size :6
# Palindrome : 926629,size :6
# Palindrome : 927729,size :6
# Palindrome : 928829,size :6
# Palindrome : 929929,size :6
# Palindrome : 9339,size :4
# Palindrome : 930039,size :6
# Palindrome : 931139,size :6
# Palindrome : 932239,size :6
# Palindrome : 933339,size :6
# Palindrome : 934439,size :6
# Palindrome : 935539,size :6
# Palindrome : 936639,size :6
# Palindrome : 937739,size :6
# Palindrome : 938839,size :6
# Palindrome : 939939,size :6
# Palindrome : 9449,size :4
# Palindrome : 940049,size :6
# Palindrome : 941149,size :6
# Palindrome : 942249,size :6
# Palindrome : 943349,size :6
# Palindrome : 944449,size :6
# Palindrome : 945549,size :6
# Palindrome : 946649,size :6
# Palindrome : 947749,size :6
# Palindrome : 948849,size :6
# Palindrome : 949949,size :6
# Palindrome : 9559,size :4
# Palindrome : 950059,size :6
# Palindrome : 951159,size :6
# Palindrome : 952259,size :6
# Palindrome : 953359,size :6
# Palindrome : 954459,size :6
# Palindrome : 955559,size :6
# Palindrome : 956659,size :6
# Palindrome : 957759,size :6
# Palindrome : 958859,size :6
# Palindrome : 959959,size :6
# Palindrome : 9669,size :4
# Palindrome : 960069,size :6
# Palindrome : 961169,size :6
# Palindrome : 962269,size :6
# Palindrome : 963369,size :6
# Palindrome : 964469,size :6
# Palindrome : 965569,size :6
# Palindrome : 966669,size :6
# Palindrome : 967769,size :6
# Palindrome : 968869,size :6
# Palindrome : 969969,size :6
# Palindrome : 9779,size :4
# Palindrome : 970079,size :6
# Palindrome : 971179,size :6
# Palindrome : 972279,size :6
# Palindrome : 973379,size :6
# Palindrome : 974479,size :6
# Palindrome : 975579,size :6
# Palindrome : 976679,size :6
# Palindrome : 977779,size :6
# Palindrome : 978879,size :6
# Palindrome : 979979,size :6
# Palindrome : 9889,size :4
# Palindrome : 980089,size :6
# Palindrome : 981189,size :6
# Palindrome : 982289,size :6
# Palindrome : 983389,size :6
# Palindrome : 984489,size :6
# Palindrome : 985589,size :6
# Palindrome : 986689,size :6
# Palindrome : 987789,size :6
# Palindrome : 988889,size :6
# Palindrome : 989989,size :6
# Palindrome : 9999,size :4
# Palindrome : 990099,size :6
# Palindrome : 991199,size :6
# Palindrome : 992299,size :6
# Palindrome : 993399,size :6
# Palindrome : 994499,size :6
# Palindrome : 995599,size :6
# Palindrome : 996699,size :6
# Palindrome : 997799,size :6
# Palindrome : 998899,size :6
# Palindrome : 999999,size :6

# %% [markdown]
# # 청킹

# %%
import nltk
nltk.download('maxent_ne_chunker')
nltk.download('words')

text = 'Namsan Botanical Garden is well known botanical garden in Seoul, Korea.'

sentences = nltk.sent_tokenize(text)

for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tags = nltk.pos_tag(words)
    
    chunks = nltk.ne_chunk(tags)
    print(chunks)
# Out:
# (S
#   (PERSON Namsan/NNP)
#   (PERSON Botanical/NNP Garden/NNP)
#   is/VBZ
#   well/RB
#   known/VBN
#   botanical/JJ
#   garden/NN
#   in/IN
#   (GPE Seoul/NNP)
#   ,/,
#   (GPE Korea/NNP)
#   ./.)
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
import nltk
nltk.download('punkt')

text = 'Ravi is the CEO of a Company. He is very powerful public speaker also.'

grammar = '\n'.join(['NP: {<DT>*<NNP>}', # DT : 한정사 ,NNP 고유명사 DT가 0번이상 출현하고 NNP출현
                    'NP: {<JJ>*<NN>}',  # JJ 형용사 NN 명사 JJ가 0번이상 출현하고 NN이 등장
                    'NP: {<NNP>+}'])
sentences = nltk.sent_tokenize(text)

for sentence in sentences:
    words = nltk.word_tokenize(sentence)
    tags = nltk.pos_tag(words)
    chunkparser = nltk.RegexpParser(grammar)
    result = chunkparser.parse(tags)
    print(result)
# Out:
# (S
#   (NP Ravi/NNP)
#   is/VBZ
#   (NP the/DT CEO/NNP)
#   of/IN
#   (NP a/DT Company/NNP)
#   ./.)
# (S
#   He/PRP
#   is/VBZ
#   very/RB
#   (NP powerful/JJ public/JJ speaker/NN)
#   also/RB
#   ./.)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import nltk
nltk.download('treebank')
nltk.download('conll2000')
from nltk.corpus import conll2000
from nltk.corpus import treebank_chunk

def mySimpleChunker():
    grammar = 'NP: {<NNP>+}'
    return nltk.RegexpParser(grammar)
def test_nothing(data):
    cp = nltk.RegexpParser('')
    print(cp.evaluate(data))
def test_mysimplechunker(data):
    schunker = mySimpleChunker()
    print(schunker.evaluate(data))
    
datasets = [
    conll2000.chunked_sents('test.txt',chunk_types=['NP']),
    treebank_chunk.chunked_sents()
]
for dataset in datasets:
    test_nothing(dataset[:50])
    test_mysimplechunker(dataset[:50])
# Out:
# ChunkParse score:
#     IOB Accuracy:  38.6%%
#     Precision:      0.0%%
#     Recall:         0.0%%
#     F-Measure:      0.0%%
# ChunkParse score:
#     IOB Accuracy:  48.2%%
#     Precision:     71.1%%
#     Recall:        17.2%%
#     F-Measure:     27.7%%
# ChunkParse score:
#     IOB Accuracy:  45.0%%
#     Precision:      0.0%%
#     Recall:         0.0%%
#     F-Measure:      0.0%%
# ChunkParse score:
#     IOB Accuracy:  50.7%%
#     Precision:     51.9%%
#     Recall:         8.8%%
#     F-Measure:     15.1%%
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     C:\Users\82102\AppData\Roaming\nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# C:\Users\82102\Anaconda3\envs\my_python\lib\site-packages\nltk\tokenize\regexp.py:130: FutureWarning: split() requires a non-empty pattern match.
#   return [tok for tok in self._regexp.split(text) if tok]

# %%
import nltk

def RDParserExample(grammar,textlist):
    parser = nltk.parse.RecursiveDescentParser(grammar)
    for text in textlist:
        sentence = nltk.word_tokenize(text)
        for tree in parser.parse(sentence):
            print(tree)
            tree.draw()
            
grammar = nltk.CFG.fromstring("""
S -> NP VP
NP -> NNP VBZ
VP -> IN NNP | DT NN IN NNP
NNP -> 'Tajmahal' | 'Agra' | 'Bangalore' | 'Karnataka'
VBZ -> 'is'
IN -> 'in' | 'of'
DT -> 'the'
NN -> 'capital'
""")

text = [
    "Tajmahal is in Agra",
    "Bangalore is the capital of Karnataka"
]

RDParserExample(grammar,text)
# Out:
# (S (NP (NNP Tajmahal) (VBZ is)) (VP (IN in) (NNP Agra)))
# (S
#   (NP (NNP Bangalore) (VBZ is))
#   (VP (DT the) (NN capital) (IN of) (NNP Karnataka)))

# %%
import nltk

def SRParserExample(grammar, textlist):
    parser = nltk.parse.ShiftReduceParser(grammar)
    for text in textlist:
        sentence = nltk.word_tokenize(text)
        print(sentence)
        for tree in parser.parse(sentence):
            print(tree)
            tree.draw()
            
text = [
    "Bangalore is the capital of Karnataka",
    "Tajmahal is in Agra",
]

grammar = nltk.CFG.fromstring("""
S -> NP VP
NP -> NNP VBZ
VP -> IN NNP | DT NN IN NNP
NNP -> 'Tajmahal' | 'Agra' | 'Bangalore' | 'Karnataka'
VBZ -> 'is'
IN -> 'in' | 'of'
DT -> 'the'
NN -> 'capital'
""")

SRParserExample(grammar,text)
# Out:
# ['Bangalore', 'is', 'the', 'capital', 'of', 'Karnataka']
# ['Tajmahal', 'is', 'in', 'Agra']
# (S (NP (NNP Tajmahal) (VBZ is)) (VP (IN in) (NNP Agra)))

# %% [markdown]
# ### Parsing DG

# %%
import nltk
grammar = nltk.grammar.DependencyGrammar.fromstring("""
'savings' -> 'small'
'yield' -> 'savings'
'gains' -> 'large'
'yield' -> 'gains'
""")
sentence = 'small savings yield large gains'
dp = nltk.parse.ProjectiveDependencyParser(grammar)
for t in sorted(dp.parse(sentence.split())):
    print(t)
    t.draw()
# Out:
# (yield (savings small) (gains large))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e8a65f4db210> in <module>
#      10 for t in sorted(dp.parse(sentence.split())):
#      11     print(t)
# ---> 12     t.draw()
#
# ~\Anaconda3\envs\my_python\lib\site-packages\nltk\tree.py in draw(self)
#     752         from nltk.draw.tree import draw_trees
#     753
# --> 754         draw_trees(self)
#     755
#     756     def pretty_print(self, sentence=None, highlight=(), stream=None, **kwargs):
#
# ~\Anaconda3\envs\my_python\lib\site-packages\nltk\draw\tree.py in draw_trees(*trees)
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#    1010
#
# ~\Anaconda3\envs\my_python\lib\site-packages\nltk\draw\tree.py in mainloop(self, *args, **kwargs)
#     996         if in_idle():
#     997             return
# --> 998         self._top.mainloop(*args, **kwargs)
#     999
#    1000
#
# ~\Anaconda3\envs\my_python\lib\tkinter\__init__.py in mainloop(self, n)
#    1281     def mainloop(self, n=0):
#    1282         """Call the mainloop of Tk."""
# -> 1283         self.tk.mainloop(n)
#    1284     def quit(self):
#    1285         """Quit the Tcl interpreter. All widgets will be destroyed."""
#
# KeyboardInterrupt:

# %% [markdown]
# ### Parsing Chart : 차트 구문 분석

# %%
from nltk.grammar import CFG
from nltk.parse.chart import ChartParser, BU_LC_STRATEGY

grammar = CFG.fromstring("""
S -> T1 T4
T1 -> NNP VBZ
T2 -> DT NN
T3 -> IN NNP
T4 -> T3 | T2 T3
NNP -> 'Tajmahal' | 'Agra' | 'Bangalore' | 'Karnataka'
VBZ -> 'is'
IN -> 'in' | 'of'
DT -> 'the'
NN -> 'capital'
""")

cp = ChartParser(grammar,BU_LC_STRATEGY,trace=True)

sentence = "Bangalore is the capital of Karnataka"

tokens = sentence.split()
chart = cp.chart_parse(tokens)
parses = list(chart.parses(grammar.start()))
print('Total Edges :',len(chart.edges()))
for tree in parses:
    print(tree)
    tree.draw()
# Out:
# |.Bangal.  is  . the  .capita.  of  .Karnat.|
# |[------]      .      .      .      .      .| [0:1] 'Bangalore'
# |.      [------]      .      .      .      .| [1:2] 'is'
# |.      .      [------]      .      .      .| [2:3] 'the'
# |.      .      .      [------]      .      .| [3:4] 'capital'
# |.      .      .      .      [------]      .| [4:5] 'of'
# |.      .      .      .      .      [------]| [5:6] 'Karnataka'
# |[------]      .      .      .      .      .| [0:1] NNP -> 'Bangalore' *
# |[------>      .      .      .      .      .| [0:1] T1 -> NNP * VBZ
# |.      [------]      .      .      .      .| [1:2] VBZ -> 'is' *
# |[-------------]      .      .      .      .| [0:2] T1 -> NNP VBZ *
# |[------------->      .      .      .      .| [0:2] S  -> T1 * T4
# |.      .      [------]      .      .      .| [2:3] DT -> 'the' *
# |.      .      [------>      .      .      .| [2:3] T2 -> DT * NN
# |.      .      .      [------]      .      .| [3:4] NN -> 'capital' *
# |.      .      [-------------]      .      .| [2:4] T2 -> DT NN *
# |.      .      [------------->      .      .| [2:4] T4 -> T2 * T3
# |.      .      .      .      [------]      .| [4:5] IN -> 'of' *
# |.      .      .      .      [------>      .| [4:5] T3 -> IN * NNP
# |.      .      .      .      .      [------]| [5:6] NNP -> 'Karnataka' *
# |.      .      .      .      .      [------>| [5:6] T1 -> NNP * VBZ
# |.      .      .      .      [-------------]| [4:6] T3 -> IN NNP *
# |.      .      .      .      [-------------]| [4:6] T4 -> T3 *
# |.      .      [---------------------------]| [2:6] T4 -> T2 T3 *
# |[=========================================]| [0:6] S  -> T1 T4 *
# Total Edges : 24
# (S
#   (T1 (NNP Bangalore) (VBZ is))
#   (T4 (T2 (DT the) (NN capital)) (T3 (IN of) (NNP Karnataka))))
