# %% [markdown]
# ## 1. import , read
# Pandas 패키지를 Import 하고 실습 데이터 파일(Ecommerce Purchases)을 read 하세요.
# 그 다음, Pandas Dataframe 형식으로 ecom 이라는 변수에 저장해보세요.

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\student\\강사님꺼\\book\\Ecommerce Purchases')

ecom = pd.DataFrame(df)
ecom
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 2                    Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE       AM
# 5     7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT       PM
# 6      93971 Conway Causeway\r\nAndersonburgh, AZ 75107  96 Xt       AM
# 7     260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG       PM
# 8             2129 Dylan Burg\r\nNew Michelle, ME 28650  45 JN       PM
# 9     3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
# 10      650 Elizabeth Park\r\nLake Maria, LA 13526-2530  65 Yn       PM
# 11             349 Laurie Parks\r\nThomasview, ID 08970  30 kK       PM
# ...

# %% [markdown]
# ## DataFrame 의 앞부분과 뒷부분 확인하여, 데이터 생긴 거 미리보기

# %%
ecom.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-8e5be197cf58> in <module>
# ----> 1 ecom.column()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'column'

# %% [markdown]
# ## .info()
# 몇 개의 컬럼과 행이 있는지 확인해보기

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Address             10000 non-null object
# Lot                 10000 non-null object
# AM or PM            10000 non-null object
# Browser Info        10000 non-null object
# Company             10000 non-null object
# Credit Card         10000 non-null int64
# CC Exp Date         10000 non-null object
# CC Security Code    10000 non-null int64
# CC Provider         10000 non-null object
# Email               10000 non-null object
# Job                 10000 non-null object
# IP Address          10000 non-null object
# Language            10000 non-null object
# Purchase Price      10000 non-null float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ## .mean()
# 평균 구매 가격(Purchase Price) 확인하기

# %%
ecom['Purchase Price'].mean()
# Out:
# 50.34730200000025

# %% [markdown]
# ### 문제1. 구매 가격(Purchase Price)의 최대값, 최소값 구하기
# ### 문제2. (문제1을 )반올림하여 구하기

# %%
mx = max(ecom['Purchase Price'])
mn = min(ecom['Purchase Price'])

round(mx,1)
round(mn,1)
# Out:
# 0.0

# %% [markdown]
# ## .count()
# 웹사이트에 얼마나 많은 사람들이 언어(Language)를 English로 하는 지 알아보기

# %% [markdown]
# ### 문제1. : # 'Language' 컬럼값이 'en' 인 데이터의 신용카드(Credit Card) 숫자 세기

# %%
ecom[ecom['Language'] == 'en']['Credit Card'].count()
# Out:
# 1098

# %% [markdown]
# ### 문제2. : # 직업('Job')이 변호사('Lawyer')인 사람수 구하기

# %%
ecom[ecom['Job'] == 'Lawyer']['Job'].count()
# Out:
# 30

# %% [markdown]
# ## .value_counts()
# ### 문제1. 얼마나 많은 사람들이 오전(AM)과 오후(PM)에 구매를 하는 지 알아보기

# %%
ecom['AM or PM'].value_counts()
# Out:
# PM    5068
# AM    4932
# Name: AM or PM, dtype: int64

# %% [markdown]
# ### 문제2. 가장 흔한 직업 상위 5개 알아보기

# %%
ecom['Job'].value_counts().head(5)
# Out:
# Interior and spatial designer        31
# Lawyer                               30
# Social researcher                    28
# Purchasing manager                   27
# Research officer, political party    27
# Name: Job, dtype: int64

# %% [markdown]
# ### 문제3. 가장 흔한 직업 하위 5개 알아보기

# %%
ecom['Job'].value_counts().tail(5)
# Out:
# Stage manager                  7
# Actuary                        6
# Editor, film/video             6
# Investment analyst             5
# Information systems manager    5
# Name: Job, dtype: int64

# %% [markdown]
# ## specific variable values

# %% [markdown]
# ### 문제1. '90 WT' 지역에서 구매된 거래 금액 확인하기

# %%
ecom[ecom['Lot']=='90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# ### 문제2. 신용카드번호 4926535242672853 이용자의 이메일 주소 찾기

# %%
ecom[ecom['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# ## 'And' or 'Or'
# ### 문제1. 얼마나 많은 사람들이 American Express 카드로 95달러 초과로 결제하는 지 알아보기

# %%
ecom[(ecom['CC Provider']=='American Express')& (ecom['Purchase Price']>95.00)]
# Out:
#                                                 Address    Lot AM or PM  \
# 9     3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
# 280   81060 Dustin Causeway Apt. 503\r\nPort Danielc...  80 zh       PM
# 372            359 Stanley Coves\r\nSalasfort, SD 59457  75 Ub       PM
# 677     4855 Peter Bridge\r\nJohnsonberg, PA 90599-0009  62 Nx       AM
# 766           386 Alisha Unions\r\nSteelebury, ND 19782  28 pJ       PM
# 1225  916 Amanda Heights\r\nNew Johnland, CA 52112-8572  09 vg       PM
# 1381  79284 Lisa Mews Suite 069\r\nKellyborough, CT ...  45 MR       PM
# 1385  67796 James Keys Suite 656\r\nSouth Katieshire...  06 ia       PM
# 1568     76108 Barker Manors\r\nEast Amy, PW 49544-5921  82 Qw       AM
# 1727  478 Anita Hill Apt. 766\r\nAverymouth, FM 5062...  94 qM       AM
# 2146         557 Barton Harbor\r\nFuentesport, VI 29961  96 MV       AM
# 2264  040 Ingram Way Suite 602\r\nEast Matthew, AR 6...  52 WA       AM
# ...

# %% [markdown]
# ### 문제2. 얼마나 많은 사람들이 95달러 초과로 결제하거나 10달러 미만으로 구매하는 지 알아보기

# %%
ecom[(ecom['Purchase Price']<10.00)| (ecom['Purchase Price']>95.00)]
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 2                    Unit 0065 Box 5052\r\nDPO AP 27450  94 vE       PM
# 9     3795 Dawson Extensions\r\nLake Tinafort, ID 88739  15 Ug       AM
# 10      650 Elizabeth Park\r\nLake Maria, LA 13526-2530  65 Yn       PM
# 13    118 Melton Via Suite 681\r\nAlexanderbury, FL ...  36 bu       PM
# 23    25292 Shepherd Trail Apt. 798\r\nRussellmouth,...  31 pS       PM
# 25    80797 Ryan Trail Apt. 752\r\nAaronhaven, MI 06...  66 SO       PM
# 30    849 Tony Unions Apt. 654\r\nSnowchester, SD 66068  76 zr       PM
# 35    93392 Webb Gardens Apt. 220\r\nLaurabury, AR 9...  37 om       AM
# 36    9374 Skinner Common Apt. 254\r\nChristopherfor...  80 Fq       PM
# 44     907 Torres Spur Suite 083\r\nJuliefurt, NJ 99332  81 Ym       PM
# 47    261 Walton Road Suite 704\r\nMaldonadoshire, M...  55 DV       PM
# ...

# %% [markdown]
# ## .apply() & Lambda
# 얼마나 많은 신용카드가 2025년에 만료되는 지 알아보기

# %%
ecom['CC Exp Date'].apply(lambda x:x.split('/')[1]=='25').value_counts()
# Out:
# False    8967
# True     1033
# Name: CC Exp Date, dtype: int64

# %% [markdown]
# ## 문제1. 얼마나 많은 신용카드가 2025년에 만료되는 지 알아보기

# %%
ecom['CC Exp Date'].apply(lambda x:x.split('/')[1]=='25').value_counts()

# %% [markdown]
# ## Lambda & .split
# ### 문제1. 가장 인기있는 이메일 제공자/호스트(e.g. gmail.com, yahoo.com, etc...) 상위 5 찾아내기

# %%
ecom['Email'].apply(lambda x:x.split('@')[1]).value_counts().head(5)
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email, dtype: int64
